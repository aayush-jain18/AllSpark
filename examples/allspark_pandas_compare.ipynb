# %%
from time import perf_counter
import pandas as pd
import numpy as np
from AllSpark.core.pd_compare import Compare

# %%
start = perf_counter()
df1 = pd.read_csv(r'D:\Project\AllSpark\tests\testdata\L3_stockquotes_20160105_BAS.csv')
df2 = pd.read_csv(r'D:\Project\AllSpark\tests\testdata\L3_stockquotes_20160105_REG.csv')
compare = Compare(left=df1, right=df2, key_columns=['symbol', 'quotedate'])
print(perf_counter() - start)
# Out:
# 2019-10-28 02:10:52,989 - INFO - _merge_dataframe: Merging dataframes for comparison, on basis of key columns :['symbol', 'quotedate']
# 0.34864309999999676

# %%
compare.diff
# Out:
#                    adjustedclose_left  adjustedclose_right adjustedclose_diff  \
# symbol quotedate
# AAN    01-05-2016              23.120                23.12                NaN
# AAP    01-05-2016             151.200               151.20                NaN
# AAPO   01-05-2016               1.000                 1.00                NaN
# AAPV   01-05-2016             102.714                 1.00            101.714
# AAPX   01-05-2016               1.000                  NaN          DIFF.TRUE
#
#                    volume_left  volume_right volume_diff  low_left  low_right  \
# symbol quotedate
# AAN    01-05-2016      1030099     1030097.0           2     22.69      22.69
# AAP    01-05-2016      1109219     1109219.0         NaN    149.89     149.89
# AAPO   01-05-2016     55077191    55077191.0         NaN    102.41     102.41
# AAPV   01-05-2016     55077191    55077191.0         NaN    102.41     102.41
# ...

# %%
compare.metadata
# Out:
#               column_present         left_column left_count  \
# column
# adjustedclose           both  adjustedclose_left          5
# volume                  both         volume_left          5
# low                     both            low_left          5
# text                    both           text_left          5
# close                   both          close_left          5
# open                    both           open_left          5
# high                    both           high_left          5
# extra             right_only                 NaN        NaN
#
#                       right_column right_count         diff_column diff_count
# column
# adjustedclose  adjustedclose_right           4  adjustedclose_diff          2
# volume                volume_right           4         volume_diff          2
# low                      low_right           4            low_diff          1
# text                    text_right           4           text_diff          3
# ...

# %%
compare.style_differ()
# Out:
# C:\Users\Aayush Jain\AppData\Roaming\Python\Python37\site-packages\pandas\core\indexing.py:896: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_nested_tuple(tup)
# <style  type="text/css" >
#     #T_a47e3fe8_f8c2_11e9_83a8_b46bfc691b02 tr:hover {
#           background-color: #AED6F1;
#     }    #T_a47e3fe8_f8c2_11e9_83a8_b46bfc691b02 th {
#           text-align: center;
#           font-weight: bold;
#           background-color: #f7f7f9;
#     }    #T_a47e3fe8_f8c2_11e9_83a8_b46bfc691b02row0_col2 {
#             color:  green;
#         }    #T_a47e3fe8_f8c2_11e9_83a8_b46bfc691b02row0_col5 {
#             color:  black;
#         }    #T_a47e3fe8_f8c2_11e9_83a8_b46bfc691b02row0_col8 {
#             color:  black;
# ...

# %%
pd.util.testing.makeTimeDataFrame().index
# Out:
# DatetimeIndex(['2000-01-03', '2000-01-04', '2000-01-05', '2000-01-06',
#                '2000-01-07', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-17', '2000-01-18',
#                '2000-01-19', '2000-01-20', '2000-01-21', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-31', '2000-02-01', '2000-02-02', '2000-02-03',
#                '2000-02-04', '2000-02-07', '2000-02-08', '2000-02-09',
#                '2000-02-10', '2000-02-11'],
#               dtype='datetime64[ns]', freq='B')
