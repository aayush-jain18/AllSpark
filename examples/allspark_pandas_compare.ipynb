# %%
import pandas as pd
from AllSpark.core.pd_compare import Compare

# %%
df1 = pd.read_csv(r'D:\Project\AllSpark\tests\testdata\L3_stockquotes_20160105_BAS.csv', parse_dates=['quotedate'])
df2 = pd.read_csv(r'D:\Project\AllSpark\tests\testdata\L3_stockquotes_20160105_REG.csv', parse_dates=['quotedate'])
compare = Compare(left=df1, right=df2, key_columns=['symbol'])
# Out:
# 2019-10-30 14:54:17,749 - INFO - _merge_dataframe: Merging dataframes for comparison, on basis of key columns :['symbol']

# %%
compare.diff[sorted(compare.diff, reverse=True)]
# Out:
#         volume_right  volume_left volume_diff text_right text_left  text_diff  \
# symbol
# AAN        1030097.0      1030099           2          a         a        NaN
# AAP        1109219.0      1109219         NaN          a         b  DIFF.TRUE
# AAPL      55077191.0     55077191         NaN          a         a        NaN
# AAPO      55077191.0     55077191         NaN        1.5         1       -0.5
# AAPV      55077191.0     55077191         NaN          a         a        NaN
# AAPX             NaN     55077191   DIFF.TRUE        NaN         1  DIFF.TRUE
#
#        rows_present quotedate_right quotedate_left quotedate_diff  ...  \
# symbol                                                             ...
# AAN            both      2016-01-05     2016-01-05            NaN  ...
# AAP            both      2016-01-05     2016-01-05            NaN  ...
# AAPL           both      2016-01-05     2016-03-04     5.0976e+06  ...
# ...

# %%
compare.metadata
# Out:
#               column_present         left_column left_count  \
# column
# text                    both           text_left         11
# quotedate               both      quotedate_left         12
# high                    both           high_left         12
# open                    both           open_left         12
# close                   both          close_left         12
# adjustedclose           both  adjustedclose_left         11
# volume                  both         volume_left         12
# low                     both            low_left         12
# extra             right_only                 NaN        NaN
#
#                       right_column right_count         diff_column diff_count
# column
# text                    text_right          10           text_diff          3
# quotedate          quotedate_right          11      quotedate_diff          2
# high                    high_right          11           high_diff          1
# ...

# %%
compare.style_differ()
# Out:
# c:\users\aayush jain\appdata\local\programs\python\python37\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
# <style  type="text/css" >
#     #T_0c4ea8f4_faf7_11e9_b9d1_b46bfc691b02 tr:hover {
#           background-color: #AED6F1;
#     }    #T_0c4ea8f4_faf7_11e9_b9d1_b46bfc691b02 th {
#           text-align: center;
#           font-weight: bold;
#           background-color: #f7f7f9;
#     }    #T_0c4ea8f4_faf7_11e9_b9d1_b46bfc691b02row0_col2 {
#             background-color:  ;
#         }    #T_0c4ea8f4_faf7_11e9_b9d1_b46bfc691b02row0_col5 {
#             background-color:  ;
#         }    #T_0c4ea8f4_faf7_11e9_b9d1_b46bfc691b02row0_col8 {
# ...
